# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
def normalize_data(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

# %%
alpha = 0.4
beta = 0.9

x = np.arange(0.01, 1, 0.01)
y = np.arange(0.01, 1, 0.01)
# y = np.repeat(1, 99)

# %%
yv, xv = 0.5, 0.5
zz = beta*yv + (alpha**(-1*np.abs(yv-0.5))*(1-xv))/beta
zz
# Out:
# 1.0055555555555555

# %%
xv, yv = np.meshgrid(x, y, indexing='ij')

# %%
zz = beta*yv + (alpha**((-1*np.abs(yv-0.5))*(1-xv)))/beta
zz = normalize_data(zz)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

h = plt.contourf(xv, yv, zz)
plt.axis('scaled')
plt.xlabel("variability")
plt.ylabel("confidence")
cbar = plt.colorbar()
cbar.ax.set_ylabel("Cartography metric")
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

my_col = cm.jet(zz/np.amax(zz))

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
surf = ax.plot_surface(xv, yv, zz, facecolors=my_col)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
gamma = 2
epoch = 10

x = np.arange(0.01, 1, 0.01)
y = np.repeat(1, 99)
y = y * x**(gamma / epoch)

# %%
fig = plt.figure()
plt.xlabel("difficulty")
plt.ylabel("relaxed_loss")
plt.title(f"gamma = {gamma}, epoch = {epoch}")
plt.plot(x, y)

# %%
fig = plt.figure()
plt.plot(x, y)
